# %%
import matminer
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, f1_score, precision_score, recall_score

# %%
df_sc = pd.read_csv("df_sc_ep_ElementProperty_Magpie_ftd.csv").dropna()
df_sc
# Out:
#                             composition     Tc  \
# 0                       Ba0.4K0.6Fe2As2  31.20
# 1             Ca0.4Ba1.25La1.25Cu3O6.98  40.10
# 2                          Mo0.39Ru0.61   6.90
# 3                            Tm4Os6Sn19   1.10
# 4             Nd1Bi0.99Pb0.01S2F0.3O0.7   4.85
# ...                                 ...    ...
# 16409                             Al4C3   0.00
# 16410                      Nb0.96Ta0.04   8.87
# 16411  Pb2Sr2Ho0.5Ca0.5Cu2.982Al0.018O8  63.60
# 16412              Yb0.5Pr0.5Ba2Cu3O6.9  34.80
# 16413                            La5Si3   1.60
#
#                                  _Composition  MagpieData minimum Number  \
# 0                          Ba0.4 K0.6 Fe2 As2                       19.0
# 1               Ca0.4 Ba1.25 La1.25 Cu3 O6.98                        8.0
# 2                               Mo0.39 Ru0.61                       42.0
# 3                                Tm4 Os6 Sn19                       50.0
# 4              Nd1 Bi0.99 Pb0.01 S2 F0.3 O0.7                        8.0
# ...                                       ...                        ...
# 16409                                  Al4 C3                        6.0
# 16410                           Nb0.96 Ta0.04                       41.0
# 16411  Pb2 Sr2 Ho0.5 Ca0.5 Cu2.982 Al0.018 O8                        8.0
# 16412                Yb0.5 Pr0.5 Ba2 Cu3 O6.9                        8.0
# 16413                                 La5 Si3                       14.0
#
#        MagpieData maximum Number  MagpieData range Number  \
# 0                           56.0                     37.0
# 1                           57.0                     49.0
# 2                           44.0                      2.0
# 3                           76.0                     26.0
# 4                           83.0                     75.0
# ...                          ...                      ...
# 16409                       13.0                      7.0
# 16410                       73.0                     32.0
# 16411                       82.0                     74.0
# 16412                       70.0                     62.0
# 16413                       57.0                     43.0
#
#        MagpieData mean Number  MagpieData avg_dev Number  \
# 0                   30.360000                   6.214400
# 1                   22.677795                  16.074864
# 2                   43.220000                   0.951600
# 3                   58.000000                  10.482759
# 4                   36.658000                  27.869600
# ...                       ...                        ...
# 16409               10.000000                   3.428571
# 16410               42.280000                   2.457600
# 16411               27.138250                  19.616202
# 16412               24.705426                  17.870921
# 16413               40.875000                  20.156250
#
#        MagpieData mode Number  MagpieData minimum MendeleevNumber  ...  \
# 0                        26.0                                 3.0  ...
# 1                         8.0                                 7.0  ...
# 2                        44.0                                50.0  ...
# 3                        50.0                                37.0  ...
# 4                        16.0                                19.0  ...
# ...                       ...                                 ...  ...
# 16409                    13.0                                73.0  ...
# 16410                    41.0                                47.0  ...
# 16411                     8.0                                 7.0  ...
# 16412                     8.0                                 9.0  ...
# 16413                    57.0                                13.0  ...
#
#        MagpieData range GSmagmom  MagpieData mean GSmagmom  \
# 0                       2.110663                  0.844265
# 1                       0.000000                  0.000000
# 2                       0.000000                  0.000000
# 3                       0.000000                  0.000000
# 4                       0.000000                  0.000000
# ...                          ...                       ...
# 16409                   0.000000                  0.000000
# 16410                   0.000000                  0.000000
# 16411                   0.000000                  0.000000
# 16412                   0.000000                  0.000000
# 16413                   0.000000                  0.000000
#
#        MagpieData avg_dev GSmagmom  MagpieData mode GSmagmom  \
# 0                         1.013118                       0.0
# 1                         0.000000                       0.0
# 2                         0.000000                       0.0
# 3                         0.000000                       0.0
# 4                         0.000000                       0.0
# ...                            ...                       ...
# 16409                     0.000000                       0.0
# 16410                     0.000000                       0.0
# 16411                     0.000000                       0.0
# 16412                     0.000000                       0.0
# 16413                     0.000000                       0.0
#
#        MagpieData minimum SpaceGroupNumber  \
# 0                                    166.0
# 1                                     12.0
# 2                                    194.0
# 3                                    141.0
# 4                                     12.0
# ...                                    ...
# 16409                                194.0
# 16410                                229.0
# 16411                                 12.0
# 16412                                 12.0
# 16413                                194.0
#
#        MagpieData maximum SpaceGroupNumber  MagpieData range SpaceGroupNumber  \
# 0                                    229.0                               63.0
# 1                                    229.0                              217.0
# 2                                    229.0                               35.0
# 3                                    194.0                               53.0
# 4                                    225.0                              213.0
# ...                                    ...                                ...
# 16409                                225.0                               31.0
# 16410                                229.0                                0.0
# 16411                                225.0                              213.0
# 16412                                229.0                              217.0
# 16413                                227.0                               33.0
#
#        MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 0                            203.800000                            30.240000
# 1                            106.949534                           102.911141
# 2                            207.650000                            16.653000
# 3                            159.275862                            23.947681
# 4                             72.206000                            49.328776
# ...                                 ...                                  ...
# 16409                        211.714286                            15.183673
# 16410                        229.000000                             0.000000
# 16411                        117.531250                           105.531250
# 16412                        110.488372                           105.359654
# 16413                        206.375000                            15.468750
#
#        MagpieData mode SpaceGroupNumber
# 0                                 166.0
# 1                                  12.0
# 2                                 194.0
# 3                                 141.0
# 4                                  70.0
# ...                                 ...
# 16409                             225.0
# 16410                             229.0
# 16411                              12.0
# 16412                              12.0
# 16413                             194.0
#
# [16375 rows x 135 columns]

# %%
df_sc = df_sc[df_sc["Tc"]>=10]
df_sc
# Out:
#                             composition     Tc  \
# 0                       Ba0.4K0.6Fe2As2  31.20
# 1             Ca0.4Ba1.25La1.25Cu3O6.98  40.10
# 6            La1.71Sr0.29Cu0.94Co0.06O4  33.00
# 10                      Nb3Sn0.85Tl0.15  18.20
# 11         Pb0.5Cu0.5Sr0.9La1.1Cu1O5.16  28.10
# ...                                 ...    ...
# 16400             Dy1Ba2Cu2.8Zn0.2O6.95  13.00
# 16401             Bi2Ca2.5Sm0.5Cu2O8.33  22.00
# 16408    La1.78Sr0.22Cu0.9975Zn0.0025O4  19.25
# 16411  Pb2Sr2Ho0.5Ca0.5Cu2.982Al0.018O8  63.60
# 16412              Yb0.5Pr0.5Ba2Cu3O6.9  34.80
#
#                                  _Composition  MagpieData minimum Number  \
# 0                          Ba0.4 K0.6 Fe2 As2                       19.0
# 1               Ca0.4 Ba1.25 La1.25 Cu3 O6.98                        8.0
# 6              La1.71 Sr0.29 Cu0.94 Co0.06 O4                        8.0
# 10                          Nb3 Sn0.85 Tl0.15                       41.0
# 11              Pb0.5 Cu1.5 Sr0.9 La1.1 O5.16                        8.0
# ...                                       ...                        ...
# 16400               Dy1 Ba2 Cu2.8 Zn0.2 O6.95                        8.0
# 16401               Bi2 Ca2.5 Sm0.5 Cu2 O8.33                        8.0
# 16408      La1.78 Sr0.22 Cu0.9975 Zn0.0025 O4                        8.0
# 16411  Pb2 Sr2 Ho0.5 Ca0.5 Cu2.982 Al0.018 O8                        8.0
# 16412                Yb0.5 Pr0.5 Ba2 Cu3 O6.9                        8.0
#
#        MagpieData maximum Number  MagpieData range Number  \
# 0                           56.0                     37.0
# 1                           57.0                     49.0
# 6                           57.0                     49.0
# 10                          81.0                     40.0
# 11                          82.0                     74.0
# ...                          ...                      ...
# 16400                       66.0                     58.0
# 16401                       83.0                     75.0
# 16408                       57.0                     49.0
# 16411                       82.0                     74.0
# 16412                       70.0                     62.0
#
#        MagpieData mean Number  MagpieData avg_dev Number  \
# 0                   30.360000                   6.214400
# 1                   22.677795                  16.074864
# 6                   24.195714                  18.509388
# 10                  44.412500                   5.118750
# 11                  24.310044                  18.375508
# ...                       ...                        ...
# 16400               24.772201                  18.002594
# 16401               24.242661                  19.035620
# 16408               24.403214                  18.746531
# 16411               27.138250                  19.616202
# 16412               24.705426                  17.870921
#
#        MagpieData mode Number  MagpieData minimum MendeleevNumber  ...  \
# 0                        26.0                                 3.0  ...
# 1                         8.0                                 7.0  ...
# 6                         8.0                                 8.0  ...
# 10                       41.0                                47.0  ...
# 11                        8.0                                 8.0  ...
# ...                       ...                                 ...  ...
# 16400                     8.0                                 9.0  ...
# 16401                     8.0                                 7.0  ...
# 16408                     8.0                                 8.0  ...
# 16411                     8.0                                 7.0  ...
# 16412                     8.0                                 9.0  ...
#
#        MagpieData range GSmagmom  MagpieData mean GSmagmom  \
# 0                       2.110663                  0.844265
# 1                       0.000000                  0.000000
# 6                       1.548471                  0.013273
# 10                      0.000000                  0.000000
# 11                      0.000000                  0.000000
# ...                          ...                       ...
# 16400                   0.000000                  0.000000
# 16401                   0.000000                  0.000000
# 16408                   0.000000                  0.000000
# 16411                   0.000000                  0.000000
# 16412                   0.000000                  0.000000
#
#        MagpieData avg_dev GSmagmom  MagpieData mode GSmagmom  \
# 0                         1.013118                       0.0
# 1                         0.000000                       0.0
# 6                         0.026318                       0.0
# 10                        0.000000                       0.0
# 11                        0.000000                       0.0
# ...                            ...                       ...
# 16400                     0.000000                       0.0
# 16401                     0.000000                       0.0
# 16408                     0.000000                       0.0
# 16411                     0.000000                       0.0
# 16412                     0.000000                       0.0
#
#        MagpieData minimum SpaceGroupNumber  \
# 0                                    166.0
# 1                                     12.0
# 6                                     12.0
# 10                                   141.0
# 11                                    12.0
# ...                                    ...
# 16400                                 12.0
# 16401                                 12.0
# 16408                                 12.0
# 16411                                 12.0
# 16412                                 12.0
#
#        MagpieData maximum SpaceGroupNumber  MagpieData range SpaceGroupNumber  \
# 0                                    229.0                               63.0
# 1                                    229.0                              217.0
# 6                                    225.0                              213.0
# 10                                   229.0                               88.0
# 11                                   225.0                              213.0
# ...                                    ...                                ...
# 16400                                229.0                              217.0
# 16401                                225.0                              213.0
# 16408                                225.0                              213.0
# 16411                                225.0                              213.0
# 16412                                229.0                              217.0
#
#        MagpieData mean SpaceGroupNumber  MagpieData avg_dev SpaceGroupNumber  \
# 0                            203.800000                            30.240000
# 1                            106.949534                           102.911141
# 6                             95.447143                            95.368163
# 10                           208.987500                            30.018750
# 11                           101.290393                           100.597910
# ...                                 ...                                  ...
# 16400                        108.432432                           103.506626
# 16401                         79.547293                            91.032425
# 16408                         95.391786                            95.304898
# 16411                        117.531250                           105.531250
# 16412                        110.488372                           105.359654
#
#        MagpieData mode SpaceGroupNumber
# 0                                 166.0
# 1                                  12.0
# 6                                  12.0
# 10                                229.0
# 11                                 12.0
# ...                                 ...
# 16400                              12.0
# 16401                              12.0
# 16408                              12.0
# 16411                              12.0
# 16412                              12.0
#
# [6248 rows x 135 columns]

# %%
X = df_sc.iloc[:, 3:]
y = df_sc['Tc']

# %%
df_sc['Tc']
# Out:
# 0        31.20
# 1        40.10
# 6        33.00
# 10       18.20
# 11       28.10
#          ...
# 16400    13.00
# 16401    22.00
# 16408    19.25
# 16411    63.60
# 16412    34.80
# Name: Tc, Length: 6248, dtype: float64

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (4686, 132)

# %%
# Build the model
model = RandomForestRegressor()

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Evaluate the model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits

# %%
# Print evaluation metrics
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, y_pred)))
print("Adjusted R-squared:", r2_score(y_test, y_pred, multioutput='uniform_average'))
# Out:
# Mean Squared Error (MSE): 114.00642806605562
# R-squared: 0.8674465678003462
# Mean Absolute Error (MAE): 6.63935088509373
# Root Mean Squared Error (RMSE): 10.677379269561216
# Adjusted R-squared: 0.8674465678003462

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       49.824858      0.549715         0.140626        0.000001
# 1      100.659089      0.472008         0.249999        0.039527
# 2      201.852554      2.850063         0.468749        0.045287
# 3       45.190498      0.585918         0.109378        0.039529
# 4       90.055995      0.840769         0.218750        0.051349
# ..            ...           ...              ...             ...
# 76      25.740277      0.180678         0.063877        0.002755
# 77      54.417476      1.484792         0.110894        0.003036
# 78      12.703090      0.334826         0.034375        0.006251
# 79      27.196309      0.384763         0.056249        0.007653
# 80      52.159582      7.972809         0.090393        0.018386
#
#    param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0             None                      1                       2
# 1             None                      1                       2
# 2             None                      1                       2
# 3             None                      1                       5
# 4             None                      1                       5
# ..             ...                    ...                     ...
# 76              20                      4                       5
# 77              20                      4                       5
# 78              20                      4                      10
# 79              20                      4                      10
# 80              20                      4                      10
#
#    param_n_estimators                                             params  \
# 0                  50  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 1                 100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 2                 200  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 3                  50  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 4                 100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# ..                ...                                                ...
# 76                100  {'max_depth': 20, 'min_samples_leaf': 4, 'min_...
# 77                200  {'max_depth': 20, 'min_samples_leaf': 4, 'min_...
# 78                 50  {'max_depth': 20, 'min_samples_leaf': 4, 'min_...
# 79                100  {'max_depth': 20, 'min_samples_leaf': 4, 'min_...
# 80                200  {'max_depth': 20, 'min_samples_leaf': 4, 'min_...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0         -108.703283        -126.965161        -128.258291
# 1         -109.272867        -125.035972        -129.451332
# 2         -110.094774        -126.199986        -123.931248
# 3         -114.725106        -132.417324        -129.334749
# 4         -111.628572        -128.663589        -125.551262
# ..                ...                ...                ...
# 76        -117.364884        -138.091503        -136.869099
# 77        -116.770507        -135.994562        -136.807160
# 78        -120.933357        -140.129810        -140.469731
# 79        -118.159197        -139.472825        -140.176514
# 80        -120.232679        -139.527429        -140.016483
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0         -116.306622        -124.992614      -121.045194        7.448943
# 1         -112.848794        -122.516441      -119.825081        7.577326
# 2         -115.550643        -121.445518      -119.444434        5.871134
# 3         -118.409615        -123.089510      -123.595261        6.581746
# 4         -116.000414        -123.131091      -120.994985        6.273843
# ..                ...                ...              ...             ...
# 76        -124.779664        -128.509759      -129.122981        7.719197
# 77        -120.876960        -131.300845      -128.350007        8.106804
# 78        -124.531368        -135.157251      -132.244303        8.071568
# 79        -124.628849        -131.443813      -130.776240        8.502019
# 80        -124.500775        -133.477878      -131.551049        7.960035
#
#     rank_test_score
# 0                 8
# 1                 3
# 2                 2
# 3                21
# 4                 7
# ..              ...
# 76               41
# 77               33
# 78               52
# 79               47
# 80               49
#
# [81 rows x 17 columns]

# %%
# Assuming you have the 'best_model' already trained
filename = 'sc_ep_best_model_rf__2.pkl'
with open(filename, 'wb') as f:
    pickle.dump(best_model, f)

# %%
# Mean Squared Error (MSE): 128.98800337163584
# R-squared: 0.8252465683616537
# Mean Absolute Error (MAE): 5.709746142892196
# Root Mean Squared Error (RMSE): 11.357288557205713
# Adjusted R-squared: 0.8252465683616537

# %%
# # Example: Create a new data point (features) for prediction
# new_data_point = [[feature1_value, feature2_value, ...]]

# # Predict using the loaded model
# predicted_value = loaded_model.predict(new_data_point)

# print("Predicted value:", predicted_value)

# %%
# Mean Squared Error (MSE): 3.6857372748369126e-06
# R-squared: 0.9973982295162389
# Mean Absolute Error (MAE): 6.51226710603105e-05
# Root Mean Squared Error (RMSE): 0.0019198274075647823
# Adjusted R-squared: 0.9973982295162389

# %% [raw]
# # Superconductivity
# df_sc_ep = pd.read_csv("df_sc_ep_ElementProperty_Magpie_ftd.csv").dropna()
#
# df_sc_ep = df_sc_ep.iloc[0:700]
#
# X = df_sc_ep.iloc[:, 3:]
# y = df_sc_ep['Tc']
#
# # Train-Test Split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# # Build the model
# model = RandomForestRegressor()
#
# # Hyperparameter tuning using GridSearchCV
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [None, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }
#
# grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
# grid_search.fit(X_train, y_train)
#
# # Evaluate the model
# best_model = grid_search.best_estimator_
# y_pred = best_model.predict(X_test)
#
# # Print evaluation metrics
# print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
# print("R-squared:", r2_score(y_test, y_pred))

# %% [raw]
# # Define a function to create the target column
# def is_semiconductor(Tc):
#     # A semiconductor has a band gap between 0.1 and 4 eV
#     return 0.1 <= Tc <= 4
